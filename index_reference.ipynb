# %% [markdown]
# ## データ参照

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
kaisai_date = "20251026"

RESULT_DIR = Path(".", "result")

# %%
index_results_df = pd.read_csv(RESULT_DIR / f"results_index_{kaisai_date}.csv", encoding="shift-jis")

# %%
state_list = list(set(index_results_df["場所"].values))
state_list
# Out:
# ['京都', '新潟', '東京']

# %%
index_results_df[index_results_df["場所"] == state_list[0]] \
    .query("R == 7") \
    .sort_values(by="総合妙味度順位")
# Out:
#     場所  R  馬番         馬名  騎手妙味度  騎手妙味度順位   種牡馬妙味度  種牡馬妙味度順位   調教師妙味度  \
# 92  福島  7  12     カジカライズ  113.6      1.0   97.429       9.0  103.500
# 82  福島  7   2  ハッピーサプライズ  109.2      3.0   97.571       8.0  102.333
# 91  福島  7  11   ピアストイヤーズ  111.6      2.0  110.571       2.0   86.714
# 88  福島  7   8      ホリーアン   92.6     10.0  115.286       1.0   92.333
# 87  福島  7   7  ホウオウブースター  101.2      5.0  103.333       4.0   94.857
# 94  福島  7  14    ルクスアドラー   93.2      9.0  107.714       3.0   96.571
# 93  福島  7  13     ダイヤモンド   96.6      7.0   99.167       7.0   99.286
# 95  福島  7  15    ゴッドヴァレー   94.8      8.0   89.429      13.0  108.714
# 84  福島  7   4   カウンターセブン  102.2      4.0   93.286      11.0   85.857
# 90  福島  7  10   ラストクリスマス   75.4     14.0  102.167       5.0   99.429
# 83  福島  7   3  ヒデノブルースカイ  100.6      6.0   80.600      14.0   91.143
# 96  福島  7  16    ツィスカリーゼ   82.2     13.0  100.667       6.0   74.000
# 81  福島  7   1   スマッシュアウト    NaN      NaN   89.500      12.0   93.833
# 85  福島  7   5     クリノゴッホ   89.2     12.0      NaN       NaN   87.833
# 86  福島  7   6    レッドカメリア   90.0     11.0      NaN       NaN  118.000
# 89  福島  7   9    イコノスタシス    NaN      NaN   95.000      10.0   96.833
#
#     調教師妙味度順位    妙味度合計    総合妙味度  総合妙味度順位
# 92       3.0  314.529  104.843      1.0
# 82       4.0  309.104  103.035      2.0
# 91      14.0  308.885  102.962      3.0
# 88      11.0  300.219  100.073      4.0
# 87       9.0  299.390   99.797      5.0
# 94       8.0  297.485   99.162      6.0
# 93       6.0  295.053   98.351      7.0
# 95       2.0  292.943   97.648      8.0
# 84      15.0  281.343   93.781      9.0
# 90       5.0  276.996   92.332     10.0
# 83      12.0  272.343   90.781     11.0
# 96      16.0  256.867   85.622     12.0
# 81      10.0      NaN      NaN      NaN
# 85      13.0      NaN      NaN      NaN
# 86       1.0      NaN      NaN      NaN
# 89       7.0      NaN      NaN      NaN

# %%
index_results_df[index_results_df["場所"] == state_list[1]] \
    .query("R == 1") \
    .sort_values(by="総合妙味度順位")
# Out:
#      場所  R  馬番         馬名  騎手妙味度  騎手妙味度順位   種牡馬妙味度  種牡馬妙味度順位   調教師妙味度  \
# 185  東京  1  10  リアライズリバティ   99.8      7.0  137.000       1.0  105.000
# 180  東京  1   5     ドナソラーレ  100.4      6.0  108.571       3.0  105.000
# 178  東京  1   3    ダイヤテソーロ   96.4     10.0  111.833       2.0  104.714
# 189  東京  1  14   ヨドノサファイア  102.2      4.0  100.333       7.0  107.667
# 179  東京  1   4    カタッポチャン  109.8      1.0   98.286       8.0   87.500
# 182  東京  1   7    トランスマーレ   95.6     11.0   98.000       9.0   97.000
# 176  東京  1   1    ベンテンカグラ  105.8      2.0   89.857      12.0   89.667
# 181  東京  1   6       ガミーヌ   89.8     13.0  105.714       4.0   85.667
# 190  東京  1  15   ミセスジョーンズ   95.4     12.0   93.000      11.0   87.500
# 187  東京  1  12   カシノサルパーレ   88.0     14.0   88.000      13.0   89.833
# 177  東京  1   2       マカレイ    NaN      NaN  104.000       5.0   96.000
# 183  東京  1   8     チャチャット  101.6      5.0  103.667       6.0      NaN
# 184  東京  1   9    トレニアムーン    NaN      NaN   94.333      10.0  101.000
# 186  東京  1  11  ミュージックレイン   98.2      9.0      NaN       NaN   77.143
# 188  東京  1  13     ニシノマーレ  104.2      3.0      NaN       NaN   90.500
# 191  東京  1  16   フロンテアムーン   98.4      8.0      NaN       NaN   93.667
#
#      調教師妙味度順位    妙味度合計    総合妙味度  総合妙味度順位
# 185       2.0  341.800  113.933      1.0
# 180       2.0  313.971  104.657      2.0
# 178       4.0  312.947  104.316      3.0
# 189       1.0  310.200  103.400      4.0
# 179      12.0  295.586   98.529      5.0
# 182       6.0  290.600   96.867      6.0
# 176      11.0  285.324   95.108      7.0
# 181      14.0  281.181   93.727      8.0
# 190      12.0  275.900   91.967      9.0
# 187      10.0  265.833   88.611     10.0
# 177       7.0      NaN      NaN      NaN
# 183       NaN      NaN      NaN      NaN
# 184       5.0      NaN      NaN      NaN
# 186      15.0      NaN      NaN      NaN
# 188       9.0      NaN      NaN      NaN
# 191       8.0      NaN      NaN      NaN

# %%
index_results_df[index_results_df["場所"] == state_list[2]] \
    .query("R == 12") \
    .sort_values(by="総合妙味度順位")
# Out:
#      場所   R  馬番         馬名    騎手妙味度  騎手妙味度順位   種牡馬妙味度  種牡馬妙味度順位   調教師妙味度  \
# 325  東京  12   6   フィーチャリング   99.500      8.0  104.125       5.0  113.000
# 322  東京  12   3   ユイノオールイン   89.667     13.0  116.750       1.0  104.375
# 327  東京  12   8   セブンマイスター   92.500     12.0  105.333       2.0  109.625
# 331  東京  12  12     プルシャプラ   97.667      9.0  104.333       4.0  105.333
# 320  東京  12   1   ジェシーテソーロ  103.500      1.0   93.000      13.0  102.000
# 323  東京  12   4  ハウリングウィンド   93.333     11.0  103.125       7.0  102.000
# 321  東京  12   2   オリーブグリーン   89.167     14.0  104.125       5.0  102.500
# 329  東京  12  10  エドワードバローズ  102.833      3.0   98.000       9.0   93.500
# 333  東京  12  14   コーリンカルベラ  101.333      6.0   93.500      12.0   99.333
# 332  東京  12  13      グアラニア  102.833      3.0  100.875       8.0   88.750
# 330  東京  12  11  ティアップドライブ  102.000      5.0   97.625      10.0   92.500
# 328  東京  12   9   キチロクキャップ   94.167     10.0   92.375      14.0  103.250
# 335  東京  12  16    エヌマエリシュ   99.833      7.0   85.286      15.0   98.000
# 334  東京  12  15    マリンバンカー   76.167     15.0  104.833       3.0   74.167
# 324  東京  12   5    チュウワチーフ  103.000      2.0      NaN       NaN  101.375
# 326  東京  12   7   キョウエイカンセ      NaN      NaN   94.167      11.0   97.250
#
#      調教師妙味度順位    妙味度合計    総合妙味度  総合妙味度順位
# 325       1.0  316.625  105.542      1.0
# 322       4.0  310.792  103.597      2.0
# 327       2.0  307.458  102.486      3.0
# 331       3.0  307.333  102.444      4.0
# 320       7.0  298.500   99.500      5.0
# 323       7.0  298.458   99.486      6.0
# 321       6.0  295.792   98.597      7.0
# 329      13.0  294.333   98.111      8.0
# 333      10.0  294.166   98.055      9.0
# 332      15.0  292.458   97.486     10.0
# 330      14.0  292.125   97.375     11.0
# 328       5.0  289.792   96.597     12.0
# 335      11.0  283.119   94.373     13.0
# 334      16.0  255.167   85.056     14.0
# 324       9.0      NaN      NaN      NaN
# 326      12.0      NaN      NaN      NaN
